// %% [markdown]
// ## Add gradle dependencies to IJava
// ## By default gradle task: RuntimeClasspath

// %%
%%gradle

println """
Welcome to Gradle $gradle.gradleVersion - http://www.gradle.org
Java Version: ${JavaVersion.current()}
Gradle home is set to: $gradle.gradleHomeDir
Gradle user directory is set to: $gradle.gradleUserHomeDir
"""
    
dependencies {
    api(
            "tech.tablesaw:tablesaw-core:0.43.1",
            "tech.tablesaw:tablesaw-jsplot:0.43.1",
    )
}
// Out:
// <-------------> 0% CONFIGURING s]> root project
// > Configure project :
//
// Welcome to Gradle 7.4.2 - http://www.gradle.org
// Java Version: 17
// Gradle home is set to: /home/jovyan/.gradle/wrapper/dists/gradle-7.4.2-bin/48ivgl02cpt2ed3fh9dbalvx8/gradle-7.4.2
// Gradle user directory is set to: /home/jovyan/.gradle
//
//
//
//
// <-------------> 0% EXECUTING s]> :RuntimeClasspath > Resolve dependencies of :runtimeClasspath
// <-------------> 0% EXECUTING s]
// > Task :RuntimeClasspath
// RuntimeClasspath: /tmp/180b3e42-c5fd-4b71-907d-23f2416c68ff/build/classes/java/main
// RuntimeClasspath: /tmp/180b3e42-c5fd-4b71-907d-23f2416c68ff/build/resources/main
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/tech.tablesaw/tablesaw-jsplot/0.43.1/cd1e4803fb71579936b238066706ab15332d929b/tablesaw-jsplot-0.43.1.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/tech.tablesaw/tablesaw-core/0.43.1/2205ccd55e05df36a02ed5364b4dcdeed1bbd8c0/tablesaw-core-0.43.1.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.google.guava/guava/30.0-jre/8ddbc8769f73309fe09b54c5951163f10b0d89fa/guava-30.0-jre.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/org.apache.commons/commons-math3/3.6.1/e4ba98f1d4b3c80ec46392f25e094a6a2e58fcbf/commons-math3-3.6.1.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/it.unimi.dsi/fastutil/8.3.0/742307990505e3a149c9c60825ffc1db5ceef02e/fastutil-8.3.0.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/org.roaringbitmap/RoaringBitmap/0.9.25/528fb3befc96737a49266c12e086c0fadd8719df/RoaringBitmap-0.9.25.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.univocity/univocity-parsers/2.8.4/c3fadbbecfadd8b9a9911eb2d06d9cf9a873edaa/univocity-parsers-2.8.4.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.ibm.icu/icu4j/65.1/b56801548aeb2f75ee3fbb42b11790f07f7d0f/icu4j-65.1.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/io.github.classgraph/classgraph/4.8.60/153ede9d717449ff915f4c7889530e1647306a0/classgraph-4.8.60.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/io.pebbletemplates/pebble/3.1.2/869cf04044953bd231472a877170c105cfe79bfc/pebble-3.1.2.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/org.slf4j/slf4j-api/1.7.30/b5a4b6d16ab13e34a88fae84c35cd5d68cac922c/slf4j-api-1.7.30.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.fasterxml.jackson.core/jackson-annotations/2.13.2/ec18851f1976d5b810ae1a5fcc32520d2d38f77a/jackson-annotations-2.13.2.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.fasterxml.jackson.core/jackson-core/2.13.2/a6a0e0620d51833feffc67bccb51937b2345763/jackson-core-2.13.2.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.fasterxml.jackson.core/jackson-databind/2.13.2.1/919754c0de3c2f22187e07318da1766f7583b5f7/jackson-databind-2.13.2.1.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.google.guava/failureaccess/1.0.1/1dcf1de382a0bf95a3d8b0849546c88bac1292c9/failureaccess-1.0.1.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.google.guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/b421526c5f297295adef1c886e5246c39d4ac629/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.google.code.findbugs/jsr305/3.0.2/25ea2e8b0c338a877313bd4672d3fe056ea78f0d/jsr305-3.0.2.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/org.checkerframework/checker-qual/3.5.0/2f50520c8abea66fbd8d26e481d3aef5c673b510/checker-qual-3.5.0.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.google.errorprone/error_prone_annotations/2.3.4/dac170e4594de319655ffb62f41cbd6dbb5e601e/error_prone_annotations-2.3.4.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/com.google.j2objc/j2objc-annotations/1.3/ba035118bc8bac37d7eff77700720999acd9986d/j2objc-annotations-1.3.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/org.roaringbitmap/shims/0.9.25/2f8109894e38b996fb1e679263057cceeaf86b11/shims-0.9.25.jar
// RuntimeClasspath: /home/jovyan/.gradle/caches/modules-2/files-2.1/org.unbescape/unbescape/1.1.6.RELEASE/7b90360afb2b860e09e8347112800d12c12b2a13/unbescape-1.1.6.RELEASE.jar
//
// BUILD SUCCESSFUL in 332ms
// 1 actionable task: 1 executed

// %% [markdown]
// ## import dependencies

// %%
import tech.tablesaw.api.*;
import static tech.tablesaw.aggregate.AggregateFunctions.*;
import tech.tablesaw.aggregate.NumericAggregateFunction;
import tech.tablesaw.plotly.*;
import tech.tablesaw.plotly.api.AreaPlot;
import tech.tablesaw.plotly.components.*;

StringColumn nc = StringColumn.create("name", new String[] {"A", "A", "B", "B"});
DoubleColumn nc2 = DoubleColumn.create("score",  new double[] {1, 2, 3, 4});
DoubleColumn nc3 = DoubleColumn.create("score2",  new double[] {5, 3, 3, 4});

System.out.println(nc);
System.out.println(nc.where(nc.isEqualTo("A")).print());
System.out.println(Table.create().addColumns(nc, nc2).print(2));
Table df = Table.create().addColumns(nc, nc2, nc3);
Table df1 = Table.create().addColumns(nc, nc2, nc3);
Table df2 = Table.create().addColumns(nc2);
Table df3 = Table.create().addColumns(nc3);
display(nc2.where(nc2.isIn(nc3.asDoubleArray())).print());
display(df2.concat(df3));
display(df.append(df1));
df.summarize("score", mean, sum, min, max).by(nc);
NumericAggregateFunction ff = new NumericAggregateFunction("ff") {
    public Double summarize(NumericColumn<?> column) {
        return Double.valueOf(column.getDouble(0));
    }
};
df.summarize("score","score2", ff, max).by(nc);
// Out:
// String column: name
// Column: name
// A
// A
//
//  name  |  score  |
// ------------------
//     A  |      1  |
//   ...  |    ...  |
//     B  |      4  |
// Column: score
// 3
// 4
//  score  |  score2  |
// --------------------
//      1  |       5  |
//      2  |       3  |
//      3  |       3  |
//      4  |       4  |
//  name  |  score  |  score2  |
// -----------------------------
//     A  |      1  |       5  |
//     A  |      2  |       3  |
//     B  |      3  |       3  |
//     B  |      4  |       4  |
//     A  |      1  |       5  |
//     A  |      2  |       3  |
//     B  |      3  |       3  |
//     B  |      4  |       4  |
//                               null summary
//  name  |  ff [score2]  |  Max [score2]  |  ff [score]  |  Max [score]  |
// ------------------------------------------------------------------------
//     A  |            5  |             5  |           1  |            2  |
//     B  |            3  |             4  |           3  |            4  |

// %% [markdown]
// ## Run gradle task: task

// %%
%%gradle task

dependencies {
    api(
            "tech.tablesaw:tablesaw-core:0.43.1",
            "tech.tablesaw:tablesaw-jsplot:0.43.1",
    )
}
// Out:
// <-------------> 0% CONFIGURING s]> root project
// <-------------> 0% EXECUTING s]> :tasks
// > Task :tasks
//
// ------------------------------------------------------------
// Tasks runnable from root project '40bd476c-a940-4404-ad8a-daefe748422b'
// ------------------------------------------------------------
//
// Build tasks
// -----------
// assemble - Assembles the outputs of this project.
// build - Assembles and tests this project.
// buildDependents - Assembles and tests this project and all projects that depend on it.
// buildNeeded - Assembles and tests this project and all projects it depends on.
// classes - Assembles main classes.
// clean - Deletes the build directory.
// jar - Assembles a jar archive containing the main classes.
// testClasses - Assembles test classes.
//
// Build Setup tasks
// -----------------
// init - Initializes a new Gradle build.
// wrapper - Generates Gradle wrapper files.
//
// Documentation tasks
// -------------------
// javadoc - Generates Javadoc API documentation for the main source code.
//
// Help tasks
// ----------
// buildEnvironment - Displays all buildscript dependencies declared in root project '40bd476c-a940-4404-ad8a-daefe748422b'.
// dependencies - Displays all dependencies declared in root project '40bd476c-a940-4404-ad8a-daefe748422b'.
// dependencyInsight - Displays the insight into a specific dependency in root project '40bd476c-a940-4404-ad8a-daefe748422b'.
// help - Displays a help message.
// javaToolchains - Displays the detected java toolchains.
// outgoingVariants - Displays the outgoing variants of root project '40bd476c-a940-4404-ad8a-daefe748422b'.
// projects - Displays the sub-projects of root project '40bd476c-a940-4404-ad8a-daefe748422b'.
// properties - Displays the properties of root project '40bd476c-a940-4404-ad8a-daefe748422b'.
// tasks - Displays the tasks runnable from root project '40bd476c-a940-4404-ad8a-daefe748422b'.
//
// Verification tasks
// ------------------
// check - Runs all checks.
// test - Runs the test suite.
//
// Rules
// -----
// Pattern: clean<TaskName>: Cleans the output files of a task.
// Pattern: build<ConfigurationName>: Assembles the artifacts of a configuration.
//
// To see all tasks and more detail, run gradle tasks --all
//
// To see more detail about a task, run gradle help --task <task>
//
// BUILD SUCCESSFUL in 213ms
// 1 actionable task: 1 executed

// %% [markdown]
// ## Run gradle task: dependencies

// %%
%%gradle dependencies

dependencies {
    api(
            "tech.tablesaw:tablesaw-core:0.43.1",
            "tech.tablesaw:tablesaw-jsplot:0.43.1",
    )
}
// Out:
// <-------------> 0% CONFIGURING s]> root project
// <-------------> 0% EXECUTING s]> :dependencies > Resolve dependencies of :compileClasspath
// <-------------> 0% EXECUTING s]
// > Task :dependencies
//
// ------------------------------------------------------------
// Root project '17fcaed7-2456-4f62-aa19-fab475fd9d9a'
// ------------------------------------------------------------
//
// annotationProcessor - Annotation processors and their dependencies for source set 'main'.
// No dependencies
//
// api - API dependencies for source set 'main'. (n)
// +--- tech.tablesaw:tablesaw-core:0.43.1 (n)
// \--- tech.tablesaw:tablesaw-jsplot:0.43.1 (n)
//
// apiElements - API elements for main. (n)
// No dependencies
//
// archives - Configuration for archive artifacts. (n)
// No dependencies
//
// compileClasspath - Compile classpath for source set 'main'.
// +--- tech.tablesaw:tablesaw-core:0.43.1
// |    +--- com.google.guava:guava:30.0-jre
// |    |    +--- com.google.guava:failureaccess:1.0.1
// |    |    +--- com.google.guava:listenablefuture:9999.0-empty-to-avoid-conflict-with-guava
// |    |    +--- com.google.code.findbugs:jsr305:3.0.2
// |    |    +--- org.checkerframework:checker-qual:3.5.0
// |    |    +--- com.google.errorprone:error_prone_annotations:2.3.4
// |    |    \--- com.google.j2objc:j2objc-annotations:1.3
// |    +--- org.apache.commons:commons-math3:3.6.1
// |    +--- it.unimi.dsi:fastutil:8.3.0
// |    +--- org.roaringbitmap:RoaringBitmap:0.9.25
// |    +--- com.univocity:univocity-parsers:2.8.4
// |    +--- com.ibm.icu:icu4j:65.1
// |    +--- io.github.classgraph:classgraph:4.8.60
// |    \--- org.slf4j:slf4j-api:1.7.30
// \--- tech.tablesaw:tablesaw-jsplot:0.43.1
//      +--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1
//      |    +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1
//      |    |         +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2 (c)
//      |    |         +--- com.fasterxml.jackson.core:jackson-core:2.13.2 (c)
//      |    |         \--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1 (c)
//      |    +--- com.fasterxml.jackson.core:jackson-core:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1 (*)
//      |    \--- com.fasterxml.jackson:jackson-bom:2.13.2.1 (*)
//      +--- io.pebbletemplates:pebble:3.1.2
//      |    +--- org.unbescape:unbescape:1.1.6.RELEASE
//      |    \--- org.slf4j:slf4j-api:1.7.25 -> 1.7.30
//      \--- tech.tablesaw:tablesaw-core:0.43.1 (*)
//
// compileOnly - Compile only dependencies for source set 'main'. (n)
// No dependencies
//
// compileOnlyApi - Compile only API dependencies for source set 'main'. (n)
// No dependencies
//
// default - Configuration for default artifacts. (n)
// No dependencies
//
// implementation - Implementation only dependencies for source set 'main'. (n)
// No dependencies
//
// mainSourceElements - List of source directories contained in the Main SourceSet. (n)
// No dependencies
//
// runtimeClasspath - Runtime classpath of source set 'main'.
// +--- tech.tablesaw:tablesaw-core:0.43.1
// |    +--- com.google.guava:guava:30.0-jre
// |    |    +--- com.google.guava:failureaccess:1.0.1
// |    |    +--- com.google.guava:listenablefuture:9999.0-empty-to-avoid-conflict-with-guava
// |    |    +--- com.google.code.findbugs:jsr305:3.0.2
// |    |    +--- org.checkerframework:checker-qual:3.5.0
// |    |    +--- com.google.errorprone:error_prone_annotations:2.3.4
// |    |    \--- com.google.j2objc:j2objc-annotations:1.3
// |    +--- org.apache.commons:commons-math3:3.6.1
// |    +--- it.unimi.dsi:fastutil:8.3.0
// |    +--- org.roaringbitmap:RoaringBitmap:0.9.25
// |    |    \--- org.roaringbitmap:shims:0.9.25
// |    +--- com.univocity:univocity-parsers:2.8.4
// |    +--- com.ibm.icu:icu4j:65.1
// |    +--- io.github.classgraph:classgraph:4.8.60
// |    \--- org.slf4j:slf4j-api:1.7.30
// \--- tech.tablesaw:tablesaw-jsplot:0.43.1
//      +--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1
//      |    +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1
//      |    |         +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2 (c)
//      |    |         +--- com.fasterxml.jackson.core:jackson-core:2.13.2 (c)
//      |    |         \--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1 (c)
//      |    +--- com.fasterxml.jackson.core:jackson-core:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1 (*)
//      |    \--- com.fasterxml.jackson:jackson-bom:2.13.2.1 (*)
//      +--- io.pebbletemplates:pebble:3.1.2
//      |    +--- org.unbescape:unbescape:1.1.6.RELEASE
//      |    \--- org.slf4j:slf4j-api:1.7.25 -> 1.7.30
//      \--- tech.tablesaw:tablesaw-core:0.43.1 (*)
//
// runtimeElements - Elements of runtime for main. (n)
// No dependencies
//
// runtimeOnly - Runtime only dependencies for source set 'main'. (n)
// No dependencies
//
// testAnnotationProcessor - Annotation processors and their dependencies for source set 'test'.
// No dependencies
//
// testCompileClasspath - Compile classpath for source set 'test'.
// +--- tech.tablesaw:tablesaw-core:0.43.1
// |    +--- com.google.guava:guava:30.0-jre
// |    |    +--- com.google.guava:failureaccess:1.0.1
// |    |    +--- com.google.guava:listenablefuture:9999.0-empty-to-avoid-conflict-with-guava
// |    |    +--- com.google.code.findbugs:jsr305:3.0.2
// |    |    +--- org.checkerframework:checker-qual:3.5.0
// |    |    +--- com.google.errorprone:error_prone_annotations:2.3.4
// |    |    \--- com.google.j2objc:j2objc-annotations:1.3
// |    +--- org.apache.commons:commons-math3:3.6.1
// |    +--- it.unimi.dsi:fastutil:8.3.0
// |    +--- org.roaringbitmap:RoaringBitmap:0.9.25
// |    +--- com.univocity:univocity-parsers:2.8.4
// |    +--- com.ibm.icu:icu4j:65.1
// |    +--- io.github.classgraph:classgraph:4.8.60
// |    \--- org.slf4j:slf4j-api:1.7.30
// \--- tech.tablesaw:tablesaw-jsplot:0.43.1
//      +--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1
//      |    +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1
//      |    |         +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2 (c)
//      |    |         +--- com.fasterxml.jackson.core:jackson-core:2.13.2 (c)
//      |    |         \--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1 (c)
//      |    +--- com.fasterxml.jackson.core:jackson-core:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1 (*)
//      |    \--- com.fasterxml.jackson:jackson-bom:2.13.2.1 (*)
//      +--- io.pebbletemplates:pebble:3.1.2
//      |    +--- org.unbescape:unbescape:1.1.6.RELEASE
//      |    \--- org.slf4j:slf4j-api:1.7.25 -> 1.7.30
//      \--- tech.tablesaw:tablesaw-core:0.43.1 (*)
//
// testCompileOnly - Compile only dependencies for source set 'test'. (n)
// No dependencies
//
// testImplementation - Implementation only dependencies for source set 'test'. (n)
// No dependencies
//
// testResultsElementsForTest - Directory containing binary results of running tests for the test Test Suite's test target. (n)
// No dependencies
//
// testRuntimeClasspath - Runtime classpath of source set 'test'.
// +--- tech.tablesaw:tablesaw-core:0.43.1
// |    +--- com.google.guava:guava:30.0-jre
// |    |    +--- com.google.guava:failureaccess:1.0.1
// |    |    +--- com.google.guava:listenablefuture:9999.0-empty-to-avoid-conflict-with-guava
// |    |    +--- com.google.code.findbugs:jsr305:3.0.2
// |    |    +--- org.checkerframework:checker-qual:3.5.0
// |    |    +--- com.google.errorprone:error_prone_annotations:2.3.4
// |    |    \--- com.google.j2objc:j2objc-annotations:1.3
// |    +--- org.apache.commons:commons-math3:3.6.1
// |    +--- it.unimi.dsi:fastutil:8.3.0
// |    +--- org.roaringbitmap:RoaringBitmap:0.9.25
// |    |    \--- org.roaringbitmap:shims:0.9.25
// |    +--- com.univocity:univocity-parsers:2.8.4
// |    +--- com.ibm.icu:icu4j:65.1
// |    +--- io.github.classgraph:classgraph:4.8.60
// |    \--- org.slf4j:slf4j-api:1.7.30
// \--- tech.tablesaw:tablesaw-jsplot:0.43.1
//      +--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1
//      |    +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1
//      |    |         +--- com.fasterxml.jackson.core:jackson-annotations:2.13.2 (c)
//      |    |         +--- com.fasterxml.jackson.core:jackson-core:2.13.2 (c)
//      |    |         \--- com.fasterxml.jackson.core:jackson-databind:2.13.2.1 (c)
//      |    +--- com.fasterxml.jackson.core:jackson-core:2.13.2
//      |    |    \--- com.fasterxml.jackson:jackson-bom:2.13.2 -> 2.13.2.1 (*)
//      |    \--- com.fasterxml.jackson:jackson-bom:2.13.2.1 (*)
//      +--- io.pebbletemplates:pebble:3.1.2
//      |    +--- org.unbescape:unbescape:1.1.6.RELEASE
//      |    \--- org.slf4j:slf4j-api:1.7.25 -> 1.7.30
//      \--- tech.tablesaw:tablesaw-core:0.43.1 (*)
//
// testRuntimeOnly - Runtime only dependencies for source set 'test'. (n)
// No dependencies
//
// (c) - dependency constraint
// (*) - dependencies omitted (listed previously)
//
// (n) - Not resolved (configuration is not meant to be resolved)
//
// A web-based, searchable dependency report is available by adding the --scan option.
//
// BUILD SUCCESSFUL in 406ms
// 1 actionable task: 1 executed
//
//
//
// <=============> 100% EXECUTING s]> IDLE

// %% [markdown]
// ## Using existing build.gradle
// ## Add gradle dependencies to IJava
// ## By default gradle task: RuntimeClasspath

// %%
%%bash 
mkdir -p /tmp/test_project
echo 'println "Welcome to Gradle $gradle.gradleVersion - http://www.gradle.org" ' > /tmp/test_project/build.gradle
cat /tmp/test_project/build.gradle
// Out:
// println "Welcome to Gradle $gradle.gradleVersion - http://www.gradle.org"

// %%
%gradle /tmp/test_project/build.gradle
// Out:
// > Configure project :
// Welcome to Gradle 7.4.2 - http://www.gradle.org
//
// > Task :RuntimeClasspath
// RuntimeClasspath: /tmp/test_project/build/classes/java/main
// RuntimeClasspath: /tmp/test_project/build/resources/main
//
// BUILD SUCCESSFUL in 93ms
// 1 actionable task: 1 executed
//
//
// <-------------> 0% WAITING

// %% [markdown]
// ## Using existing build.gradle with gradle task: properties

// %%
%gradle /tmp/testproject/build.gradle properties
// Out:
// > Configure project :
// Welcome to Gradle 7.4.2 - http://www.gradle.org
//
//
//
// <-------------> 0% EXECUTING s]> :properties
// > Task :properties
//
// ------------------------------------------------------------
// Root project 'testproject'
// ------------------------------------------------------------
//
// RuntimeClasspath: task ':RuntimeClasspath'
// allprojects: [root project 'testproject']
// ant: org.gradle.api.internal.project.DefaultAntBuilder@1ce0c821
// antBuilderFactory: org.gradle.api.internal.project.DefaultAntBuilderFactory@2fd0f9ec
// archivesBaseName: testproject
// artifacts: org.gradle.api.internal.artifacts.dsl.DefaultArtifactHandler_Decorated@57622b08
// asDynamicObject: DynamicObject for root project 'testproject'
// autoTargetJvmDisabled: false
// base: extension 'base'
// baseClassLoaderScope: org.gradle.api.internal.initialization.DefaultClassLoaderScope@7c480b4
// buildDir: /tmp/testproject/build
// buildFile: /tmp/testproject/build.gradle
// buildPath: :
// buildScriptSource: org.gradle.groovy.scripts.TextResourceScriptSource@1dffe1ad
// buildscript: org.gradle.api.internal.initialization.DefaultScriptHandler@35487467
// childProjects: {}
// class: class org.gradle.api.internal.project.DefaultProject_Decorated
// classLoaderScope: org.gradle.api.internal.initialization.DefaultClassLoaderScope@73b423ad
// clean: task ':clean'
// components: SoftwareComponentInternal set
// configurationActions: org.gradle.configuration.project.DefaultProjectConfigurationActionContainer@5056dc4f
// configurationTargetIdentifier: org.gradle.configuration.ConfigurationTargetIdentifier$1@32c6bd61
// configurations: configuration container
// convention: org.gradle.internal.extensibility.DefaultConvention@445b0c12
// crossProjectModelAccess: org.gradle.api.internal.project.DefaultCrossProjectModelAccess@16a0f67f
// defaultArtifacts: extension 'defaultArtifacts'
// defaultTasks: []
// deferredProjectConfiguration: org.gradle.api.internal.project.DeferredProjectConfiguration@7072f440
// dependencies: org.gradle.api.internal.artifacts.dsl.dependencies.DefaultDependencyHandler_Decorated@77d8729a
// dependencyLocking: org.gradle.internal.locking.DefaultDependencyLockingHandler_Decorated@6bffdbef
// dependencyMetaDataProvider: org.gradle.internal.service.scopes.ProjectScopeServices$ProjectBackedModuleMetaDataProvider@7a7dcbe1
// depth: 0
// description: null
// detachedState: false
// displayName: root project 'testproject'
// distsDirName: distributions
// distsDirectory: extension 'base' property 'distsDirectory'
// docsDir: /tmp/testproject/build/docs
// docsDirName: docs
// ext: org.gradle.internal.extensibility.DefaultExtraPropertiesExtension@1dcaf01a
// extensions: org.gradle.internal.extensibility.DefaultConvention@445b0c12
// fileOperations: org.gradle.api.internal.file.DefaultFileOperations@29320d9b
// fileResolver: org.gradle.api.internal.file.BaseDirFileResolver@3c878bf1
// gradle: build 'testproject'
// group:
// identityPath: :
// inheritedScope: org.gradle.internal.extensibility.ExtensibleDynamicObject$InheritedDynamicObject@28b17d43
// internalStatus: property(java.lang.Object, fixed(class java.lang.String, integration))
// java: extension 'java'
// javaToolchains: extension 'javaToolchains'
// layout: org.gradle.api.internal.file.DefaultProjectLayout@6231026f
// libsDirName: libs
// libsDirectory: extension 'base' property 'libsDirectory'
// listenerBuildOperationDecorator: org.gradle.configuration.internal.DefaultListenerBuildOperationDecorator@5bd68567
// logger: org.gradle.internal.logging.slf4j.OutputEventListenerBackedLogger@1a09afdf
// logging: org.gradle.internal.logging.services.DefaultLoggingManager@5b8e45ef
// model: root project 'testproject'
// modelIdentityDisplayName: null
// modelRegistry: org.gradle.model.internal.registry.DefaultModelRegistry@78f670b8
// name: testproject
// normalization: org.gradle.normalization.internal.DefaultInputNormalizationHandler_Decorated@123e27b3
// objects: org.gradle.api.internal.model.DefaultObjectFactory@7dac752e
// owner: root project 'testproject'
// parent: null
// parentIdentifier: null
// path: :
// pluginContext: false
// pluginManager: org.gradle.api.internal.plugins.DefaultPluginManager_Decorated@5424f649
// plugins: [org.gradle.language.base.plugins.LifecycleBasePlugin@1f9c2fc5, org.gradle.api.plugins.BasePlugin@7cfc903a, org.gradle.api.plugins.JvmEcosystemPlugin@62679f8e, org.gradle.api.plugins.ReportingBasePlugin@1102ab35, org.gradle.api.plugins.JavaBasePlugin$Inject@6f1e4cd7, org.gradle.testing.base.plugins.TestSuiteBasePlugin@77fb6c4e, org.gradle.api.plugins.JvmTestSuitePlugin@29be16d0, org.gradle.api.plugins.JavaPlugin@2de15bd1, org.gradle.api.plugins.JavaLibraryPlugin@3084c24e, org.gradle.api.plugins.HelpTasksPlugin@1cb1510c, org.gradle.buildinit.plugins.BuildInitPlugin@45e0ccdc, org.gradle.buildinit.plugins.WrapperPlugin@62782862]
// processOperations: org.gradle.process.internal.DefaultExecActionFactory$DecoratingExecActionFactory@747810d1
// project: root project 'testproject'
// projectConfigurator: org.gradle.api.internal.project.BuildOperationCrossProjectConfigurator@62d71663
// projectDir: /tmp/testproject
// projectEvaluationBroadcaster: ProjectEvaluationListener broadcast
// projectEvaluator: org.gradle.configuration.project.LifecycleProjectEvaluator@2112a0c9
// projectPath: :
// properties: {...}
// providers: org.gradle.api.internal.provider.DefaultProviderFactory_Decorated@20ab7b1
// publicType: org.gradle.api.plugins.BasePluginConvention
// reporting: extension 'reporting'
// reportsDir: /tmp/testproject/build/reports
// repositories: repository container
// resources: org.gradle.api.internal.resources.DefaultResourceHandler@3640c1b9
// rootDir: /tmp/testproject
// rootProject: root project 'testproject'
// rootScript: false
// script: false
// scriptHandlerFactory: org.gradle.api.internal.initialization.DefaultScriptHandlerFactory@6c7ead1c
// scriptPluginFactory: org.gradle.configuration.ScriptPluginFactorySelector@585e5cb2
// serviceRegistryFactory: org.gradle.internal.service.scopes.ProjectScopeServices$$Lambda$1122/0x00000008018f7c50@5cd464dd
// services: ProjectScopeServices
// sourceCompatibility: 17
// sourceSets: SourceSet container
// standardOutputCapture: org.gradle.internal.logging.services.DefaultLoggingManager@5b8e45ef
// state: project state 'EXECUTED'
// status: integration
// subprojects: []
// targetCompatibility: 17
// taskThatOwnsThisObject: null
// tasks: task set
// testReportDir: /tmp/testproject/build/reports/tests
// testReportDirName: tests
// testResultsDir: /tmp/testproject/build/test-results
// testResultsDirName: test-results
// testing: extension 'testing'
// version: unspecified
//
// BUILD SUCCESSFUL in 115ms
// 1 actionable task: 1 executed
