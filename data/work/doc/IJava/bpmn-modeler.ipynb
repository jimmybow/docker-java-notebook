// %%
%%js
require.config({
    paths: {
      'jquery': 'https://code.jquery.com/jquery-3.3.1.min',
      'bpmn-modeler': 'https://unpkg.com/bpmn-js@14.0.0/dist/bpmn-modeler.development'
    }
});
require(['jquery', 'bpmn-modeler'], function($, BpmnJS) {
  window.$ = $;
  window.BpmnJS = BpmnJS;
});
// Out:
// <script >require.config({
//     paths: {
//       'jquery': 'https://code.jquery.com/jquery-3.3.1.min',
//       'bpmn-modeler': 'https://unpkg.com/bpmn-js@14.0.0/dist/bpmn-modeler.development'
//     }
// });
// require(['jquery', 'bpmn-modeler'], function($, BpmnJS) {
//   window.$ = $;
//   window.BpmnJS = BpmnJS;
// });</script>

// %%
// 等待 js 載入
Thread.sleep(2000);

// %%
%%js
bpmnXML = `

<?xml version="1.0" encoding="UTF-8"?>
<definitions xmlns="http://www.omg.org/spec/BPMN/20100524/MODEL" xmlns:bpmndi="http://www.omg.org/spec/BPMN/20100524/DI" xmlns:omgdc="http://www.omg.org/spec/DD/20100524/DC" xmlns:omgdi="http://www.omg.org/spec/DD/20100524/DI" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" targetNamespace="" exporter="Camunda Modeler" exporterVersion="4.12.0" xsi:schemaLocation="http://www.omg.org/spec/BPMN/20100524/MODEL http://www.omg.org/spec/BPMN/2.0/20100501/BPMN20.xsd">
<collaboration id="sid-c0e745ff-361e-4afb-8c8d-2a1fc32b1424">
<participant id="sid-87F4C1D6-25E1-4A45-9DA7-AD945993D06F" name="DEMO" processRef="BPMN_DEMO" />
</collaboration>
<process id="BPMN_DEMO" name="DEMO" processType="None" isClosed="false" isExecutable="true">
<extensionElements />
<laneSet id="sid-b167d0d7-e761-4636-9200-76b7f0e8e83a">
  <lane id="sid-57E4FE0D-18E4-478D-BC5D-B15164E93254" name=".">
    <flowNodeRef>start</flowNodeRef>
    <flowNodeRef>end</flowNodeRef>
  </lane>
</laneSet>
<startEvent id="start" name="start">
  <outgoing>Flow_1s1ja2f</outgoing>
</startEvent>
<sequenceFlow id="Flow_1s1ja2f" sourceRef="start" targetRef="end" />
<endEvent id="end" name="end">
  <incoming>Flow_1s1ja2f</incoming>
</endEvent>
</process>
<bpmndi:BPMNDiagram id="sid-74620812-92c4-44e5-949c-aa47393d3830">
<bpmndi:BPMNPlane id="sid-cdcae759-2af7-4a6d-bd02-53f3352a731d" bpmnElement="sid-c0e745ff-361e-4afb-8c8d-2a1fc32b1424">
  <bpmndi:BPMNShape id="sid-87F4C1D6-25E1-4A45-9DA7-AD945993D06F_gui" bpmnElement="sid-87F4C1D6-25E1-4A45-9DA7-AD945993D06F" isHorizontal="true">
    <omgdc:Bounds x="200" y="95" width="941" height="250" />
    <bpmndi:BPMNLabel labelStyle="sid-84cb49fd-2f7c-44fb-8950-83c3fa153d3b">
      <omgdc:Bounds x="47.49999999999999" y="170.42857360839844" width="12.000000000000014" height="59.142852783203125" />
    </bpmndi:BPMNLabel>
  </bpmndi:BPMNShape>
  <bpmndi:BPMNShape id="sid-57E4FE0D-18E4-478D-BC5D-B15164E93254_gui" bpmnElement="sid-57E4FE0D-18E4-478D-BC5D-B15164E93254" isHorizontal="true">
    <omgdc:Bounds x="230" y="95" width="911" height="250" />
  </bpmndi:BPMNShape>
  <bpmndi:BPMNEdge id="Flow_1s1ja2f_di" bpmnElement="Flow_1s1ja2f">
    <omgdi:waypoint x="348" y="200" />
    <omgdi:waypoint x="932" y="200" />
  </bpmndi:BPMNEdge>
  <bpmndi:BPMNShape id="StartEvent_0l6sgn0_di" bpmnElement="start">
    <omgdc:Bounds x="312" y="182" width="36" height="36" />
    <bpmndi:BPMNLabel>
      <omgdc:Bounds x="319" y="219" width="22" height="14" />
    </bpmndi:BPMNLabel>
  </bpmndi:BPMNShape>
  <bpmndi:BPMNShape id="EndEvent_0xwuvv5_di" bpmnElement="end">
    <omgdc:Bounds x="932" y="182" width="36" height="36" />
    <bpmndi:BPMNLabel>
      <omgdc:Bounds x="942" y="221" width="19" height="14" />
    </bpmndi:BPMNLabel>
  </bpmndi:BPMNShape>
</bpmndi:BPMNPlane>
<bpmndi:BPMNLabelStyle id="sid-e0502d32-f8d1-41cf-9c4a-cbb49fecf581">
  <omgdc:Font name="Arial" size="11" isBold="false" isItalic="false" isUnderline="false" isStrikeThrough="false" />
</bpmndi:BPMNLabelStyle>
<bpmndi:BPMNLabelStyle id="sid-84cb49fd-2f7c-44fb-8950-83c3fa153d3b">
  <omgdc:Font name="Arial" size="12" isBold="false" isItalic="false" isUnderline="false" isStrikeThrough="false" />
</bpmndi:BPMNLabelStyle>
</bpmndi:BPMNDiagram>
</definitions>

`;
// Out:
// <script >bpmnXML = `
//
// <?xml version="1.0" encoding="UTF-8"?>
// <definitions xmlns="http://www.omg.org/spec/BPMN/20100524/MODEL" xmlns:bpmndi="http://www.omg.org/spec/BPMN/20100524/DI" xmlns:omgdc="http://www.omg.org/spec/DD/20100524/DC" xmlns:omgdi="http://www.omg.org/spec/DD/20100524/DI" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" targetNamespace="" exporter="Camunda Modeler" exporterVersion="4.12.0" xsi:schemaLocation="http://www.omg.org/spec/BPMN/20100524/MODEL http://www.omg.org/spec/BPMN/2.0/20100501/BPMN20.xsd">
// <collaboration id="sid-c0e745ff-361e-4afb-8c8d-2a1fc32b1424">
// <participant id="sid-87F4C1D6-25E1-4A45-9DA7-AD945993D06F" name="DEMO" processRef="BPMN_DEMO" />
// </collaboration>
// <process id="BPMN_DEMO" name="DEMO" processType="None" isClosed="false" isExecutable="true">
// <extensionElements />
// <laneSet id="sid-b167d0d7-e761-4636-9200-76b7f0e8e83a">
//   <lane id="sid-57E4FE0D-18E4-478D-BC5D-B15164E93254" name=".">
// ...

// %%
%%css
.bjs-powered-by {
    display: none;
}   

svg {
  height: 400px !important;
}
// Out:
// <style>.bjs-powered-by {
//     display: none;
// }
//
// svg {
//   height: 400px !important;
// }</style>

// %%
%%html
<link rel="stylesheet" href="https://unpkg.com/bpmn-js@14.0.0/dist/assets/bpmn-js.css">
<link rel="stylesheet" href="https://unpkg.com/bpmn-js@14.0.0/dist/assets/diagram-js.css">
<link rel="stylesheet" href="https://unpkg.com/bpmn-js@14.0.0/dist/assets/bpmn-font/css/bpmn.css">
<div id="bpmn-container"></div>
// Out:
// <link rel="stylesheet" href="https://unpkg.com/bpmn-js@14.0.0/dist/assets/bpmn-js.css">
// <link rel="stylesheet" href="https://unpkg.com/bpmn-js@14.0.0/dist/assets/diagram-js.css">
// <link rel="stylesheet" href="https://unpkg.com/bpmn-js@14.0.0/dist/assets/bpmn-font/css/bpmn.css">
// <div id="bpmn-container"></div>

// %%
%%js
// modeler instance
var bpmnModeler = new BpmnJS({
    container: '#bpmn-container',
    keyboard: {
      bindTo: window
    },
    width: '100%',
    height: '100%',
    propertiesPanel: {},
    additionalModules: [{
        paletteProvider: ["value", ''], //禁用/清空左侧工具栏
        labelEditingProvider: ["value", ''], //禁用节点编辑
        contextPadProvider: ["value", ''], //禁用图形菜单
        bendpoints: ["value", {}], //禁用连线拖动
        zoomScroll: ["value", {}], //禁用滚动
        //moveCanvas: ['value', ''], //禁用拖动整个流程图
        move: ['value', ''] //禁用单个图形拖动
    }],
    moddleExtensions: []     
});
// 加载BPMN字符串
try {
  const { warnings } = bpmnModeler.importXML(bpmnXML);
  console.log('rendered');
} catch (err) {
  console.log('error rendering', err);
}
// Out:
// <script >// modeler instance
// var bpmnModeler = new BpmnJS({
//     container: '#bpmn-container',
//     keyboard: {
//       bindTo: window
//     },
//     width: '100%',
//     height: '100%',
//     propertiesPanel: {},
//     additionalModules: [{
//         paletteProvider: ["value", ''], //禁用/清空左侧工具栏
//         labelEditingProvider: ["value", ''], //禁用节点编辑
//         contextPadProvider: ["value", ''], //禁用图形菜单
//         bendpoints: ["value", {}], //禁用连线拖动
//         zoomScroll: ["value", {}], //禁用滚动
//         //moveCanvas: ['value', ''], //禁用拖动整个流程图
//         move: ['value', ''] //禁用单个图形拖动
//     }],
//     moddleExtensions: []
// });
// // 加载BPMN字符串
// try {
//   const { warnings } = bpmnModeler.importXML(bpmnXML);
//   console.log('rendered');
// } catch (err) {
//   console.log('error rendering', err);
// }</script>
