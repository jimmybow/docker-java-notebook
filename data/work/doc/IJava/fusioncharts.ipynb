// %%
%%js
require.config({
    paths: {
      'jquery': 'https://code.jquery.com/jquery-3.3.1.min',
      'fusioncharts': 'https://cdn.fusioncharts.com/fusioncharts/latest/fusioncharts',
      'fusioncharts.theme': 'https://cdn.fusioncharts.com/fusioncharts/latest/themes/fusioncharts.theme.candy',  
      'fusioncharts.jqueryplugin': 'https://rawgit.com/fusioncharts/fusioncharts-jquery-plugin/develop/dist/fusioncharts.jqueryplugin.min',
    },
    shim: {
        'fusioncharts.jqueryplugin': {
            deps: ['jquery', 'fusioncharts.theme', 'fusioncharts'],
        },
        'fusioncharts.theme': {
            deps: ['fusioncharts'],
        }        
    },
});
require(['jquery', 'fusioncharts', 'fusioncharts.theme', 'fusioncharts.jqueryplugin'], function($, Fusioncharts) {
  window.$ = $;
  window.Fusioncharts = Fusioncharts;
});
// Out:
// <script >require.config({
//     paths: {
//       'jquery': 'https://code.jquery.com/jquery-3.3.1.min',
//       'fusioncharts': 'https://cdn.fusioncharts.com/fusioncharts/latest/fusioncharts',
//       'fusioncharts.theme': 'https://cdn.fusioncharts.com/fusioncharts/latest/themes/fusioncharts.theme.candy',
//       'fusioncharts.jqueryplugin': 'https://rawgit.com/fusioncharts/fusioncharts-jquery-plugin/develop/dist/fusioncharts.jqueryplugin.min',
//     },
//     shim: {
//         'fusioncharts.jqueryplugin': {
//             deps: ['jquery', 'fusioncharts.theme', 'fusioncharts'],
//         },
//         'fusioncharts.theme': {
//             deps: ['fusioncharts'],
//         }
//     },
// });
// require(['jquery', 'fusioncharts', 'fusioncharts.theme', 'fusioncharts.jqueryplugin'], function($, Fusioncharts) {
//   window.$ = $;
//   window.Fusioncharts = Fusioncharts;
// });</script>

// %%
// 等待 js 載入
Thread.sleep(2000);

// %%
%%css
g[fill='#b1b2b7'] {
    display: none
}
// Out:
// <style>g[fill='#b1b2b7'] {
//     display: none
// }</style>

// %%
%%html
<div id="chart-container">FusionCharts will render here</div>
// Out:
// <div id="chart-container">FusionCharts will render here</div>

// %%
%%js
$("#chart-container").insertFusionCharts({
  type: "area2d",
  width: "100%",
  height: "800",
  dataFormat: "json",
  dataSource: {
    chart: {
      caption: "Yearly sales of iPhone",
      yaxisname: "Number of units sold",
      subcaption: "2007-2016",
      legendposition: "Right",
      drawanchors: "0",
      showvalues: "0",
      plottooltext: "<b>$dataValue</b> iPhones sold in $label",
      theme: "candy"
    },
    data: [
      {
        label: "2007",
        value: "1380000"
      },
      {
        label: "2008",
        value: "1450000"
      },
      {
        label: "2009",
        value: "1610000"
      },
      {
        label: "2010",
        value: "1540000"
      },
      {
        label: "2011",
        value: "1480000"
      },
      {
        label: "2012",
        value: "1573000"
      },
      {
        label: "2013",
        value: "2232000"
      },
      {
        label: "2014",
        value: "2476000"
      },
      {
        label: "2015",
        value: "2832000"
      },
      {
        label: "2016",
        value: "3808000"
      }
    ]
  }
});
// Out:
// <script >$("#chart-container").insertFusionCharts({
//   type: "area2d",
//   width: "100%",
//   height: "800",
//   dataFormat: "json",
//   dataSource: {
//     chart: {
//       caption: "Yearly sales of iPhone",
//       yaxisname: "Number of units sold",
//       subcaption: "2007-2016",
//       legendposition: "Right",
//       drawanchors: "0",
//       showvalues: "0",
//       plottooltext: "<b>$dataValue</b> iPhones sold in $label",
//       theme: "candy"
//     },
//     data: [
//       {
//         label: "2007",
//         value: "1380000"
//       },
//       {
//         label: "2008",
//         value: "1450000"
//       },
//       {
//         label: "2009",
//         value: "1610000"
//       },
//       {
//         label: "2010",
//         value: "1540000"
//       },
//       {
//         label: "2011",
//         value: "1480000"
//       },
//       {
//         label: "2012",
//         value: "1573000"
//       },
//       {
//         label: "2013",
// ...
